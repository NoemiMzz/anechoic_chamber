# %%
import pandas as pd 
import os
import matplotlib.pyplot as plt
import numpy as np
import time

# %matplotlib inline

# %%
ang_start_pos = 70
ang_end_pos = -70
angle_res=1
stepscale_mot1=5000
N_ang = int(len(np.arange(-abs(ang_start_pos), abs(ang_start_pos), angle_res))) + 1
N_ang
# Out:
# 141

# %%
print(abs(ang_end_pos-ang_start_pos)/(N_ang-1))#*5000)
# Out:
# 1.0

# %%
starting_ang = 20
ending_ang=-50
angle_res=.5
if not ending_ang:
    ending_ang=-2
else:
    ending_ang=ending_ang

# %%
(starting_ang - ending_ang)/angle_res+1
# Out:
# 141.0

# %%
print(starting_ang, ending_ang, angle_res)
# Out:
# 70 20 1

# %%
N_ang = int(len(np.arange(starting_ang, ending_ang, angle_res))) + 1

# %%
N_ang
# Out:
# 1

# %%
import Motors_Remote_Control_Ethernet as mrc

# %%
mrc.test_mot1(0, -10, 21)
# Out:
# b'PSET1=5000.0\r'

# %%
5263.157894736842/5000
# Out:
# 1.0526315789473684
